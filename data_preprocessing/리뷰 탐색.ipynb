# %%
import pandas as pd
from collections import Counter

# %%
# %pwd
# Out:
# '/home/nlp908/data/hwijeen/BOAZ/project/code/data_preprocessing'

# %%
reviews_df = pd.read_csv("../crawling/Reviews_csv/Reviews_merged_processed.csv",
                     index_col=0)
reviews_df.head(100)
# Out:
#              Id Rating                                             Review
# 0    2301428333     추천  기여@@ 운 동전@@ 지갑@@ ♡ 복@@ 실@@ 복@@ 실 기여@@ 운 털@@ 동전...
# 1    2301428333     추천  기@@ 염 깜찍@@ ^^ 털이 보@@ 슬@@ 보@@ 슬@@ .@@ 하구요@@ ~~^...
# 5    2301428333   적극추천  너무 이뻐요 ^^ 사진으로 남겨@@ 보@@ 기는 처음이에요 근데 너무너무 만족스러워...
# 6    2301428333   적극추천  강추@@ 템 털빠짐이 좀 있긴한데 처음@@ 만 그러@@ 구 괜찮아요@@ ^.^ 판매...
# 7    2301428333   적극추천  너무 귀엽@@ 습니다! 아는 동생@@ 에게 선물@@ 할@@ 겸 커플로 하려고 검은색...
# 10   2301428333     만족                                 털 부드럽고 좋아요@@ ^.^\n
# 11   2301428333     만족               친구 선물용으로 줘@@ 써@@ 여 차@@ 키링@@ 으로 조아여\n
# 12   2301428333     만족                        가방에 달@@ 고@@ 다니는@@ 중@@ 이에여\n
# 14   2301428333     만족         선물@@ 주려고 산건@@ 데.. 기냥 제가 다 쓰려구요 너무 이뻐요 ^^\n
# 15   2301428333     만족                       진짜 너무너무너무 이뻐요! 꼭 구매@@ 추천!!\n
# 18   2301428333     만족                                빠른 배송 최고@@ 에@@ 욤!\n
# 20   2429054242   적극추천  좋아요 구매하@@ 면서 언니@@ 꺼@@ 도 같이 샀어요@@ ~~~ 이어@@ 폰 보관...
# 21   2429054242   적극추천  좋아요 동전@@ 을 주머니에 넣고 다니@@ 닌 불편해서 구매했습니다. 동전 넣고 다...
# 22   2429054242   적극추천  좋아요 이어@@ 폰 보관@@ 용으로 쓰려고 샀습니다@@ ~~~~ 살짝 작긴한데 그런...
# 24   2429054242   적극추천  굳 배송 정말 빠르고 다른색상도 구입하고싶@@ 을정도로 먼가 딴@@ 딴@@ 하고 좋...
# 25   2429054242   적극추천  예뻐요 배송도 빠르고 블랙으로 주문했는데 깔끔하고 동전@@ 넣어@@ 다니기 참@@ ...
# 27   2429054242     만족                                깜찍@@ 해요.@@ 맘에@@ 듦\n
# 28   2429054242     만족                                정말@@ 작@@ 네요~ 귀여워요\n
# 30   2429054242     보통          품질@@ 대비 조금 비싼@@ 느낌이 있지만 가볍게 쓰기 편하고 예뻐요!\n
# 31   2429054242     만족                                            좋아요~~\n
# 34   2429054242     만족  핑크색 샀는데 이쁘네요 동전 혹@@ 여@@ 라도 틈@@ 으로 빠지@@ 진 않을까 했...
# 35   2429054242     만족                                            만족합니다\n
# 38   2757633970     만족                                        좋아요@@ ^^~\n
# 39   2757633970     만족  맘에 드는 동전@@ 지갑이 없었는데 딱 맘에 들어요. 배송도 빠르고 포장도 신경써주...
# 40   2757633970     만족  소재가 엄청 부드럽고 지퍼@@ 형식@@ 이 아니라서 더 편한@@ 듯하네요. 지폐@@...
# 41   2757633970     만족                                    역시@@ 최고@@ 최고!\n
# 42   2757633970     만족                                           너무 이뻐요\n
# 43   2757633970     만족                                            만족합니다\n
# 45   2757633970     보통                                            만족합니다\n
# 46   2757633970     만족                                두번째 구매입니다. 너무 이뻐용\n
# ..          ...    ...                                                ...
# 92   2522926999   적극추천  맘에 들어요 무난한 블랙@@ 이어서 사용@@ 하는데 무리가 없고 지갑이 가볍고 그@...
# 93   2522926999   적극추천  추천 다른색상으로 오배송@@ 됬@@ 지만 바로 처리해주셔서 아주@@ 빠른배송@@ 받...
# 94   2522926999   적극추천  아주@@ 좋음 사진보다 예쁘고 동전@@ 카드 지@@ 폐 모두@@ 들어가@@ 요~@@...
# 95   2522926999     만족                                   밝은 색상의 레드@@ 에요\n
# 96   2522926999     만족                                    간편하게 사용하기 좋아요\n
# 97   2522926999     만족                           배송도 엄청 빠르고 받아보니 넘 이쁘네요\n
# 98   2522926999     만족                                    바로@@ 교환 해주셨어요\n
# 99   2522926999     만족                                          배송빠름 예쁨\n
# 100  1002194299   적극추천  잘받았어요 실버@@ 와@@ 골드@@ ~ 무늬가 조금@@ 식 다릅니다 그래서 더@@ ...
# 103  1002194299   적극추천  작고@@ 귀여운 실제@@ 받아보니 너무@@ 귀여운 동전@@ 지갑@@ 이예요 동전@@...
# 104  1002194299     만족                                       마음에@@ 쏙들어요\n
# 105  1002194299     만족  실버@@ 색상 재구매@@ ~@@ 선물용@@ 이라@@ 풀어@@ 보@@ 지는@@ 않았지...
# 106  1002194299     만족                               골드@@ 색상도@@ 예쁘네요 ^^\n
# 108  1002194299     만족                 예쁘@@ 넉@@ 요~ 다른 껄@@ 러@@ 도 사고 싶어요~\n
# 109  2218429430   적극추천  예쁘고 편해요~^^ 가격도 착@@ 하고@@ ~@@ 딱 찾던 디자인이라 맘에 들어요....
# 110  2218429430     만족  너무이뻐요 중@@ 학생 딸@@ 이랑 친구랑 커플로 사줬는데 가죽도 고급스럽고 컬러도...
# 111  2218429430     만족                                 예쁘고 편해요. 만족합니다^^\n
# 112  2218429430     만족                                          잘 받았습니다\n
# 113  2218429430     만족                                        배송 빠르고 만족\n
# 114  2218429430     만족                                       배송@@ 둣 좋아여\n
# 115  2218429430     만족                     동전 많이 들어 갈@@ 거같@@ 네@@ 욘 잘쓸게요\n
# 116  2277693792     만족                        정@@ 민 깜찍하고 이뻐요~~ 감사합니다~^^\n
# 117  2277693792     만족                            생각보다 크기가 크네요 그래도 귀여워요\n
# 118  2277693792     만족                                          너무 귀여워요\n
# 119  2277693792     만족                                            아주좋아요\n
# 120  2000112840   추천안함  추천 안해요 화이트 주문햇는데 별로에요@@ 똑딱이@@ 버튼@@ 쪽 열고@@ 닫@@ ...
# 121  2000112840     불만  환불 안된@@ 대서 신중하게 주문@@ 하려고 문의했는데 판매자분 응@@ 답도 느리@...
# 122  2000112840     만족  생각보다 많이 들어가는 것 같아요. 동전 넣을 수 있어서 샀는데 디자인도 맘에 들고...
# 123  2000112840     만족                                           만족합니다~\n
# 126  2833626018     불만                                 가격 거@@ 품이 너무 심해요\n
#
# [100 rows x 3 columns]

# %%
reviews_df.pivot_table(index='Review_len_morph', values='Review', aggfunc=len)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-844c4d7f2806> in <module>()
# ----> 1 reviews_df.pivot_table(index='Review_len_morph', values='Review', aggfunc=len)
#
# ~/anaconda3/envs/hwijeen_3.6/lib/python3.6/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    4466                            aggfunc=aggfunc, fill_value=fill_value,
#    4467                            margins=margins, dropna=dropna,
# -> 4468                            margins_name=margins_name)
#    4469
#    4470     def stack(self, level=-1, dropna=True):
#
# ~/anaconda3/envs/hwijeen_3.6/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      79         values = list(values)
#      80
# ---> 81     grouped = data.groupby(keys)
#      82     agged = grouped.agg(aggfunc)
#      83
#
# ~/anaconda3/envs/hwijeen_3.6/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/envs/hwijeen_3.6/lib/python3.6/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1846         raise TypeError('invalid type: %s' % type(obj))
#    1847
# -> 1848     return klass(obj, by, **kwds)
#    1849
#    1850
#
# ~/anaconda3/envs/hwijeen_3.6/lib/python3.6/site-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     514                                                     level=level,
#     515                                                     sort=sort,
# --> 516                                                     mutated=self.mutated)
#     517
#     518         self.obj = obj
#
# ~/anaconda3/envs/hwijeen_3.6/lib/python3.6/site-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort, mutated, validate)
#    2932                 in_axis, name, level, gpr = False, None, gpr, None
#    2933             else:
# -> 2934                 raise KeyError(gpr)
#    2935         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    2936             # Add key to exclusions
#
# KeyError: 'Review_len_morph'

# %% [markdown]
# #### 길이

# %%
reviews_id = set(reviews['Id'].tolist())
print("review 가져온 상품 개수: %d" % len(reviews_id))
# Out:
# review 가져온 상품 개수: 11186

# %% [markdown]
# #### 리뷰 단어

# %%
reviews_lists = reviews_df['Review'].tolist()
reviews_list = [eval(review) for review in reviews_lists] 
reviews = [item for review in reviews_list for item in review]
words_counter = Counter(reviews)
words_counter.most_common(10)
# Out:
# [(('요', 'Eomi'), 119371),
#  (('.', 'Punctuation'), 68391),
#  (('좋', 'Adjective'), 64890),
#  (('이', 'Josa'), 64485),
#  (('에', 'Josa'), 50055),
#  (('도', 'Josa'), 47048),
#  (('아요', 'Eomi'), 37162),
#  (('가', 'Josa'), 36606),
#  (('은', 'Josa'), 35252),
#  (('네요', 'Eomi'), 34434)]

# %%
print("리뷰에 포함된 unique word 개수:", len(words_counter))
# Out:
# 리뷰에 포함된 unique word 개수: 39233

# %% [markdown]
# #### 만족도별 리뷰 개수

# %%
review_count_by_rating = reviews_df.pivot_table(index = 'Rating', values = 'Review',aggfunc = len, margins=True)
review_count_by_rating['%'] = review_count_by_rating['Review']/184963*100
review_count_by_rating
# Out:
#           Review           %
# Rating
# 만족       56128.0   30.345529
# 보통       75344.0   40.734633
# 불만       14439.0    7.806426
# 적극추천     21484.0   11.615296
# 추천       13035.0    7.047355
# 추천안함      4533.0    2.450760
# All     184963.0  100.000000

# %% [markdown]
# ### 리뷰 평균 길이

# %%
def get_review_len(df):
    """
    adds review_len column to df
    """
    review_list = df['Review'].tolist()
    review_len_list = [len(review) for review in review_list]
    df['Review_len_morph'] = review_len_list

    avg_review_len = sum(review_len_list) // len(review_len_list)
    print("리뷰 평균 길이(형태소 개수): ", avg_review_len)
    return df

# %%
reviews_all_df = get_review_len(reviews_all_df)
reviews_all_df.head()
